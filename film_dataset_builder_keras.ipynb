# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import requests
import pickle
import text_hammer as th

# %%
from convokit import Corpus, download
corpus = Corpus(filename=download("movie-corpus"))
# Out:
# Downloading movie-corpus to /Users/fabio/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
utt_df = corpus.get_utterances_dataframe().drop(columns=['vectors'])
convo_df = corpus.get_conversations_dataframe().drop(columns=['vectors'])
speaker_df = corpus.get_speakers_dataframe().drop(columns=['vectors'])

# %%
convo_df = convo_df.reset_index()
utt_df = utt_df.reset_index()
speaker_df = speaker_df.reset_index()

# %%
convo_df = convo_df.rename(columns={"id": "conversation_id"})
speaker_df = speaker_df.rename(columns={"id": "speaker"})

# %%
dataset = pd.merge(convo_df, utt_df, on=["conversation_id"])
dataset = pd.merge(dataset, speaker_df, on=["speaker"])

# %%
dataframe = dataset[["id", "conversation_id", "meta.movie_idx_x", "speaker", "meta.character_name", "meta.gender", "reply_to", "text"]]
dataframe
# Out:
#              id conversation_id meta.movie_idx_x speaker meta.character_name  \
# 0         L1045           L1044               m0      u0              BIANCA
# 1          L985            L984               m0      u0              BIANCA
# 2          L925            L924               m0      u0              BIANCA
# 3          L872            L870               m0      u0              BIANCA
# 4          L870            L870               m0      u0              BIANCA
# ...         ...             ...              ...     ...                 ...
# 304708  L666522         L666520             m616   u9034             VEREKER
# 304709  L666520         L666520             m616   u9034             VEREKER
# 304710  L666372         L666369             m616   u9034             VEREKER
# 304711  L666370         L666369             m616   u9034             VEREKER
# 304712  L666256         L666256             m616   u9034             VEREKER
#
#        meta.gender reply_to                                               text
# 0                f    L1044                                       They do not!
# 1                f     L984                                         I hope so.
# 2                f     L924                                          Let's go.
# 3                f     L871     Okay -- you're gonna need to learn how to lie.
# 4                f     None  I'm kidding.  You know how sometimes you just ...
# ...            ...      ...                                                ...
# 304708           ?  L666521  So far only their scouts. But we have had repo...
# 304709           ?     None  Well I assure you, Sir, I have no desire to cr...
# 304710           ?  L666371  I think Chelmsford wants a good man on the bor...
# 304711           ?  L666369  I'm to take the Sikali with the main column to...
# 304712           ?     None  Colonel Durnford... William Vereker. I hear yo...
#
# [304713 rows x 8 columns]

# %%
dataframe['text'].values[315]
# Out:
# 'Unwelcome.'

# %%
from classes.cleaner import Cleaner
C = Cleaner()

# %%
dataframe = C.text_preprocessing(dataframe, 'text', 'cleaned_text')
# Out:
# 100%|██████████| 304713/304713 [00:00<00:00, 3813723.86it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[column].apply(lambda x: str(x).lower()))
# 100%|██████████| 304713/304713 [00:00<00:00, 5191900.34it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(lambda x: th.cont_exp(x)))
# 100%|██████████| 304713/304713 [00:00<00:00, 4130205.19it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(lambda x: th.remove_emails(x)))
# /Users/fabio/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/bs4/__init__.py:329: MarkupResemblesLocatorWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# 100%|██████████| 304713/304713 [00:00<00:00, 5186527.64it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(lambda x: th.remove_html_tags(x)))
# 100%|██████████| 304713/304713 [00:00<00:00, 5978859.55it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(
# 100%|██████████| 304713/304713 [00:00<00:00, 5829816.24it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(
# 100%|██████████| 304713/304713 [00:00<00:00, 4072988.39it/s]
# /Users/fabio/Documents/Progetto IR/classes/cleaner.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = tqdm(df[new_col].apply(lambda x: th.make_base(x)))

# %%
dataframe = dataframe[dataframe['cleaned_text'].map(lambda d: len(d)) > 0]

# %%
with open('datasets/processed/movie_scripts_df.pickle', "wb") as w:
    pickle.dump(dataframe, w)

# %%
with open("datasets/processed/movie_scripts_df.pickle", "rb") as r:
    dataframe = pickle.load(r)

# %%
dataframe
# Out:
#              id conversation_id meta.movie_idx_x speaker meta.character_name  \
# 0         L1045           L1044               m0      u0              BIANCA
# 1          L985            L984               m0      u0              BIANCA
# 2          L925            L924               m0      u0              BIANCA
# 3          L872            L870               m0      u0              BIANCA
# 4          L870            L870               m0      u0              BIANCA
# ...         ...             ...              ...     ...                 ...
# 304708  L666522         L666520             m616   u9034             VEREKER
# 304709  L666520         L666520             m616   u9034             VEREKER
# 304710  L666372         L666369             m616   u9034             VEREKER
# 304711  L666370         L666369             m616   u9034             VEREKER
# 304712  L666256         L666256             m616   u9034             VEREKER
#
#        meta.gender reply_to  \
# 0                f    L1044
# 1                f     L984
# 2                f     L924
# 3                f     L871
# 4                f     None
# ...            ...      ...
# 304708           ?  L666521
# 304709           ?     None
# 304710           ?  L666371
# 304711           ?  L666369
# 304712           ?     None
#
#                                                      text  \
# 0                                            They do not!
# 1                                              I hope so.
# 2                                               Let's go.
# 3          Okay -- you're gonna need to learn how to lie.
# 4       I'm kidding.  You know how sometimes you just ...
# ...                                                   ...
# 304708  So far only their scouts. But we have had repo...
# 304709  Well I assure you, Sir, I have no desire to cr...
# 304710  I think Chelmsford wants a good man on the bor...
# 304711  I'm to take the Sikali with the main column to...
# 304712  Colonel Durnford... William Vereker. I hear yo...
#
#                                              cleaned_text
# 0                                             they do not
# 1                                               i hope so
# 2                                               let us go
# 3              okay you re go to need to learn how to lie
# 4       i am kid you know how sometimes you just becom...
# ...                                                   ...
# 304708  so far only their scout but we have have repor...
# 304709  well i assure you sir i have no desire to crea...
# 304710  i think chelmsford want a good man on the bord...
# 304711  i am to take the sikali with the main column t...
# 304712  colonel durnford william vereker i hear you ve...
#
# [304436 rows x 9 columns]

# %%
from classes.vectorizer import Vectorizer
V = Vectorizer()

# %%
dataframe['pad_vectorized_text'] = list(V.vectorize_keras_df(dataframe, 'cleaned_text'))

# %%
with open("datasets/processed/vectorized_scripts_df.pickle", "wb") as w:
    pickle.dump(dataframe, w)
